# %%
import pickle as pck
import warnings
warnings.filterwarnings("ignore")

# %%
load_model = pck.load(open("random_forest_model.sav", 'rb'))
input_array = load_model.feature_names_in_       #feature_names_in_ variable is used to know the expected parameters in the model
print(input_array)
# Out:
# ['age' 'bp' 'sg' 'al' 'su' 'bgr' 'bu' 'sc' 'sod' 'pot' 'hrmo' 'pcv' 'wc'
#  'rc' 'rbc_normal' 'pc_normal' 'pcc_present' 'ba_present' 'htn_yes'
#  'dm_yes' 'cad_yes' 'appet_yes' 'pe_yes' 'ane_yes']

# %%
input_list = []
for i, name in enumerate(input_array):
    prediction_input = eval(input(f"Enter Input-{name}:"))
    input_list.append(prediction_input)
# Out:
# Enter Input-age: 29
# Enter Input-bp: 100
# Enter Input-sg: 3
# Enter Input-al: 2
# Enter Input-su: 0
# Enter Input-bgr: 98
# Enter Input-bu: 26
# Enter Input-sc: 2.5
# Enter Input-sod: 138
# Enter Input-pot: 3.6
# Enter Input-hrmo: 10.7
# Enter Input-pcv: 38
# Enter Input-wc: 10300
# Enter Input-rc: 4.8
# Enter Input-rbc_normal: 1
# Enter Input-pc_normal: 0
# Enter Input-pcc_present: 0
# Enter Input-ba_present: 1
# Enter Input-htn_yes: 0
# Enter Input-dm_yes: 0
# Enter Input-cad_yes: 0
# Enter Input-appet_yes: 1
# Enter Input-pe_yes: 0
# Enter Input-ane_yes: 0

# %%
print("Future Prediction =", load_model.predict([input_list]))
# Out:
# Future Prediction = [1]
